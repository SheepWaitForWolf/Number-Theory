# %%
E = EllipticCurve([7,21])
F = EllipticCurve([5, 3/5])
G = EllipticCurve([23,345])
H = EllipticCurve ([235235,1243951270])

# %%
print(E)
print(F)
print(G)
print(H)
# Out:
# Elliptic Curve defined by y^2 = x^3 + 7*x + 21 over Rational Field
# Elliptic Curve defined by y^2 = x^3 + 5*x + 3/5 over Rational Field
# Elliptic Curve defined by y^2 = x^3 + 23*x + 345 over Rational Field
# Elliptic Curve defined by y^2 = x^3 + 235235*x + 1243951270 over Rational Field

# %%
E.modular_form()
# Out:
# q - q^5 + O(q^6)

# %%
F.modular_form()
# Out:
# q + O(q^6)

# %%
G.modular_form()
# Out:
# q - 4*q^5 + O(q^6)

# %%
H.modular_form()
# Out:
# q - 3*q^3 + O(q^6)

# %%
E.Np(7)
# Out:
# 8

# %%
E.Np(13)
# Out:
# 20

# %%
E.ap(7)
# Out:
# 0

# %%
E.ap(13)
# Out:
# -6

# %%
E.ap(11)
# Out:
# 3

# %%
ap_list = []
for i in primes_first_n(500):
    ap_list += [ E.ap(i)]

# %%
import numpy

# %%
list_plot (numpy.array(ap_list))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
ap_list2 = []
for i in primes_first_n(10000):
    ap_list2 += [ E.ap(i) ]

# %%
list_plot(numpy.array(ap_list2))
# Out:
# Graphics object consisting of 1 graphics primitive
