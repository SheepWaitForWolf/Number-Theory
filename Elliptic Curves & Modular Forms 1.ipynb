# %%
E = EllipticCurve ([2,5])
print(E)
# Out:
# Elliptic Curve defined by y^2 = x^3 + 2*x + 5 over Rational Field

# %%
E.modular_form()
# Out:
# q + 3*q^3 + 4*q^5 + O(q^6)

# %%
E.Np(5)
# Out:
# 2

# %%
E.Np(11)
# Out:
# 10

# %%
E.ap(3)
# Out:
# 3

# %%
ap_list = []
for i in primes_first_n(500):
    ap_list += [ E.ap(i)]

# %%
import numpy

# %%
list_plot (numpy.array(ap_list))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 1 graphics primitive

# %%
ap_list2 = []
for i in primes_first_n(10000):
    ap_list2 += [ E.ap(i) ]

# %%
list_plot(numpy.array(ap_list2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
This is a demonstration of the Hasse-Weil Bound : |epsilon_p| <= 2 sqrt(p)
